# %%
import numpy as np
import json
import seaborn as sns
import matplotlib.pyplot as plt

# %%
JSON_PATH = r"C:\Users\mariu\Documents\Studium\Praktikum\Evaluation\20251116_161434_Evaluation_L2\results.json"

NORMALIZE = True
ANNOT = False
CMAP = "Blues"
DIAG = False

DETAILS = {
    "name": "MoCo (resnet50, dim=128, MoCo weights)",
    "dataset": "Places365",
    "metric": "Accuracy",
    "k": 5
}

# %%
with open(JSON_PATH, "r") as f:
    data = json.load(f)

# %%
# %matplotlib qt

# for method, d1 in data.items():
#     for dataset, d2 in d1.items():
#         pass

cm = np.array(data[DETAILS["name"]][DETAILS["dataset"]]["per_class"]["matrix"][DETAILS["metric"] + "@" + str(DETAILS["k"])])

if NORMALIZE:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    fmt = ".2f"
else:
    fmt = "d"

plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=ANNOT, fmt=fmt, cmap=CMAP, cbar=True)

# Masken
diagonal_mask = np.eye(cm.shape[0], dtype=bool)
off_diag_mask = ~diagonal_mask

# Off-Diagonal Heatmap (Rot)
sns.heatmap(cm, mask=diagonal_mask, annot=ANNOT, fmt=fmt, cmap="Reds", cbar=False)

# Diagonal Heatmap (Grün) darüber plotten
sns.heatmap(cm, mask=off_diag_mask, annot=ANNOT, fmt=fmt, cmap="Greens", cbar=False)

if DIAG:
    # Diagonale markieren
    for i in range(cm.shape[0]):
        plt.gca().add_patch(plt.Rectangle((i, i), 1, 1, fill=False, edgecolor="black", lw=1))

plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()
